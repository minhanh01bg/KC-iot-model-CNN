# %%
import pandas as pd
import os 
import numpy as np

# %%
df = pd.DataFrame()
cnt = 1
dir = './ddos_rename'
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 401:
        break

df.to_csv('./split/1_400.csv',index=False)

cnt = 401

df = pd.DataFrame()
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 801:
        break

df.to_csv('./split/401_800.csv',index=False)

cnt = 801
df = pd.DataFrame()
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 1201:
        break

df.to_csv('./split/801_1200.csv',index=False)

# %%
# 1428
df = pd.DataFrame()
cnt = 1
dir = './password_attack_rename'
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 401:
        break

df.to_csv('./concat_par/1_400.csv',index=False)

cnt = 401

df = pd.DataFrame()
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 801:
        break

df.to_csv('./concat_par/401_800.csv',index=False)

cnt = 801
df = pd.DataFrame()
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 1201:
        break

df.to_csv('./concat_par/801_1200.csv',index=False)
# Out:
# (601, 84)
# 1
# (1246, 84)
# 2
# (1883, 84)
# 3
# (2494, 84)
# 4
# (3092, 84)
# 5
# (3715, 84)
# 6
# (4362, 84)
# 7
# (4986, 84)
# 8
# (5608, 84)
# 9
# (6247, 84)
# 10
# (6916, 84)
# 11
# (7490, 84)
# 12
# (8125, 84)
# 13
# (8772, 84)
# 14
# (9355, 84)
# 15
# (10000, 84)
# 16
# (10640, 84)
# 17
# (11265, 84)
# 18
# (11888, 84)
# 19
# (12501, 84)
# 20
# (13140, 84)
# 21
# (13750, 84)
# 22
# (14348, 84)
# 23
# (14952, 84)
# 24
# (15581, 84)
# 25
# (16195, 84)
# 26
# (16801, 84)
# 27
# (17399, 84)
# 28
# (18052, 84)
# 29
# (18657, 84)
# 30
# (19286, 84)
# 31
# (19942, 84)
# 32
# (20588, 84)
# 33
# (21206, 84)
# 34
# (21829, 84)
# 35
# (22479, 84)
# 36
# (23106, 84)
# 37
# (23754, 84)
# 38
# (24401, 84)
# 39
# (25044, 84)
# 40
# (25642, 84)
# 41
# (26265, 84)
# 42
# (26895, 84)
# 43
# (27551, 84)
# 44
# (28162, 84)
# 45
# (28777, 84)
# 46
# (29439, 84)
# 47
# (30062, 84)
# 48
# (30674, 84)
# 49
# (31269, 84)
# 50
# (31900, 84)
# 51
# (32522, 84)
# 52
# (33118, 84)
# 53
# (33736, 84)
# ...

# %%
# 1428
df = pd.DataFrame()
cnt = 1
dir = './port_scan_rename'
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 401:
        break

df.to_csv('./port_scan_concat/1_400.csv',index=False)

cnt = 401

df = pd.DataFrame()
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 801:
        break

df.to_csv('./port_scan_concat/401_800.csv',index=False)

cnt = 801
df = pd.DataFrame()
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 1201:
        break

df.to_csv('./port_scan_concat/801_1200.csv',index=False)
# Out:
# (4826, 84)
# 1
# (9651, 84)
# 2
# (14493, 84)
# 3
# (19319, 84)
# 4
# (24106, 84)
# 5
# (28944, 84)
# 6
# (33343, 84)
# 7
# (37911, 84)
# 8
# (42403, 84)
# 9
# (46928, 84)
# 10
# (51509, 84)
# 11
# (55975, 84)
# 12
# (60544, 84)
# 13
# (65123, 84)
# 14
# (69613, 84)
# 15
# (74127, 84)
# 16
# (78725, 84)
# 17
# (83153, 84)
# 18
# (87730, 84)
# 19
# (92177, 84)
# 20
# (96776, 84)
# 21
# (101262, 84)
# 22
# (105793, 84)
# 23
# (110317, 84)
# 24
# (114838, 84)
# 25
# (119355, 84)
# 26
# (123792, 84)
# 27
# (128390, 84)
# 28
# (132837, 84)
# 29
# (137430, 84)
# 30
# (141891, 84)
# 31
# (146365, 84)
# 32
# (150957, 84)
# 33
# (155400, 84)
# 34
# (159857, 84)
# 35
# (164446, 84)
# 36
# (168932, 84)
# 37
# (173463, 84)
# 38
# (178036, 84)
# 39
# (182539, 84)
# 40
# (187135, 84)
# 41
# (191575, 84)
# 42
# (196161, 84)
# 43
# (200660, 84)
# 44
# (205202, 84)
# 45
# (209776, 84)
# 46
# (214267, 84)
# 47
# (218801, 84)
# 48
# (223348, 84)
# 49
# (227899, 84)
# 50
# (232387, 84)
# 51
# ...

# %%
# 1428
df = pd.DataFrame()
cnt = 1
dir = './port_scan_2_rename'
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 401:
        break

df.to_csv('./port_scan_2_concat/1_400.csv',index=False)

cnt = 401

df = pd.DataFrame()
for i in range(cnt,len(os.listdir(dir))):
    df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
    df = pd.concat([df,df_temp])
    print(df.shape)
    print(cnt)
    cnt += 1
    if cnt == 801:
        break

df.to_csv('./port_scan_2_concat/401_endl.csv',index=False)

# cnt = 801
# df = pd.DataFrame()
# for i in range(cnt,len(os.listdir(dir))):
#     df_temp = pd.read_csv(dir+'/'+str(i)+'.csv')
#     df = pd.concat([df,df_temp])
#     print(df.shape)
#     print(cnt)
#     cnt += 1
#     if cnt == 1201:
#         break

# df.to_csv('./port_scan_2_concat/801_1200.csv',index=False)
# Out:
# (4966, 84)
# 1
# (9946, 84)
# 2
# (14922, 84)
# 3
# (19896, 84)
# 4
# (24869, 84)
# 5
# (29807, 84)
# 6
# (34779, 84)
# 7
# (39752, 84)
# 8
# (44724, 84)
# 9
# (49696, 84)
# 10
# (54667, 84)
# 11
# (59622, 84)
# 12
# (64596, 84)
# 13
# (69571, 84)
# 14
# (74543, 84)
# 15
# (79517, 84)
# 16
# (84488, 84)
# 17
# (89434, 84)
# 18
# (94410, 84)
# 19
# (99382, 84)
# 20
# (104360, 84)
# 21
# (109331, 84)
# 22
# (114305, 84)
# 23
# (119269, 84)
# 24
# (124240, 84)
# 25
# (129211, 84)
# 26
# (134150, 84)
# 27
# (139126, 84)
# 28
# (144100, 84)
# 29
# (149071, 84)
# 30
# (154045, 84)
# 31
# (159018, 84)
# 32
# (163989, 84)
# 33
# (168960, 84)
# 34
# (173932, 84)
# 35
# (178906, 84)
# 36
# (183846, 84)
# 37
# (188819, 84)
# 38
# (193795, 84)
# 39
# (198770, 84)
# 40
# (203734, 84)
# 41
# (208707, 84)
# 42
# (213683, 84)
# 43
# (218651, 84)
# 44
# (223621, 84)
# 45
# (228595, 84)
# 46
# (233568, 84)
# 47
# (238539, 84)
# 48
# (243516, 84)
# 49
# (248487, 84)
# 50
# (253465, 84)
# 51
# ...
