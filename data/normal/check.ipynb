# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('./test.csv')
benign = pd.read_csv('./benign.csv')

# %%
new = pd.read_csv('./1677222819120258682_ISCX.csv')

# %%
test = test.reindex(sorted(test.columns), axis=1)
benign = benign.reindex(sorted(benign.columns), axis=1)
new = new.reindex(sorted(new.columns), axis=1)

# %%
namere = {
    'ACK Flag Count' : 'ACK Flag Cnt',
    'Active Max' : 'Active Max',
    'Active Mean' : 'Active Mean',
    'Active Min' : 'Active Min',
    'Active Std' : 'Active Std',
    'Bwd Bulk Rate Avg' : 'Bwd Blk Rate Avg',
    'Bwd Bytes/Bulk Avg' : 'Bwd Byts/b Avg',
    'Bwd Header Length' : 'Bwd Header Len',
    'Bwd IAT Max' : 'Bwd IAT Max',
    'Bwd IAT Mean' : 'Bwd IAT Mean',
    'Bwd IAT Min' : 'Bwd IAT Min',
    'Bwd IAT Std' : 'Bwd IAT Std',
    'Bwd IAT Total' : 'Bwd IAT Tot',
    'Bwd PSH Flags' : 'Bwd PSH Flags',
    'Bwd Packet Length Max' : 'Bwd Pkt Len Max',
    'Bwd Packet Length Mean' : 'Bwd Pkt Len Mean',
    'Bwd Packet Length Min' : 'Bwd Pkt Len Min',
    'Bwd Packet Length Std' : 'Bwd Pkt Len Std',
    'Bwd Packet/Bulk Avg' : 'Bwd Pkts/b Avg',
    'Bwd Packets/s' : 'Bwd Pkts/s',
    'Bwd Segment Size Avg' : 'Bwd Seg Size Avg',
    'Bwd URG Flags' : 'Bwd URG Flags',
    'CWR Flag Count' : 'CWE Flag Count', #
    'Down/Up Ratio' : 'Down/Up Ratio',
    'Dst Port' : 'Dst Port',
    'ECE Flag Count' : 'ECE Flag Cnt',
    'FIN Flag Count' : 'FIN Flag Cnt',
    'Flow Bytes/s' : 'Flow Byts/s',
    'Flow Duration' : 'Flow Duration',
    'Flow IAT Max' : 'Flow IAT Max',
    'Flow IAT Mean' : 'Flow IAT Mean',
    'Flow IAT Min' : 'Flow IAT Min',
    'Flow IAT Std' : 'Flow IAT Std',
    'Flow Packets/s' : 'Flow Pkts/s',
    'Fwd Act Data Pkts' : 'Fwd Act Data Pkts',
    'Fwd Bulk Rate Avg' : 'Fwd Blk Rate Avg',
    'Fwd Bytes/Bulk Avg' : 'Fwd Byts/b Avg',
    'Fwd Header Length' : 'Fwd Header Len',
    'Fwd IAT Max' : 'Fwd IAT Max',
    'Fwd IAT Mean' : 'Fwd IAT Mean',
    'Fwd IAT Min' : 'Fwd IAT Min',
    'Fwd IAT Std' : 'Fwd IAT Std',
    'Fwd IAT Total' : 'Fwd IAT Tot',
    'Fwd PSH Flags' : 'Fwd PSH Flags',
    'Fwd Packet Length Max' : 'Fwd Pkt Len Max',
    'Fwd Packet Length Mean' : 'Fwd Pkt Len Mean',
    'Fwd Packet Length Min' : 'Fwd Pkt Len Min',
    'Fwd Packet Length Std' : 'Fwd Pkt Len Std',
    'Fwd Packet/Bulk Avg' : 'Fwd Pkts/b Avg',
    'Fwd Packets/s' : 'Fwd Pkts/s',
    'Fwd Seg Size Min' : 'Fwd Seg Size Min',
    'Fwd Segment Size Avg' : 'Fwd Seg Size Avg',
    'Fwd URG Flags' : 'Fwd URG Flags',
    'Idle Max' : 'Idle Max',
    'Idle Mean' : 'Idle Mean',
    'Idle Min' : 'Idle Min',
    'Idle Std' : 'Idle Std',
    'PSH Flag Count' : 'PSH Flag Cnt',
    'Packet Length Max' : 'Pkt Len Max',
    'Packet Length Mean' : 'Pkt Len Mean',
    'Packet Length Min' : 'Pkt Len Min',
    'Packet Length Std' : 'Pkt Len Std',
    'Packet Length Variance' : 'Pkt Len Var',
    'Average Packet Size' : 'Pkt Size Avg', #
    'Protocol' : 'Protocol',
    'RST Flag Count' : 'RST Flag Cnt',
    'SYN Flag Count' : 'SYN Flag Cnt',
    'Subflow Bwd Bytes' : 'Subflow Bwd Byts',  
    'Subflow Bwd Packets' : 'Subflow Bwd Pkts',
    'Subflow Fwd Bytes' : 'Subflow Fwd Byts',
    'Subflow Fwd Packets' : 'Subflow Fwd Pkts',
    'Timestamp' : 'Timestamp',
    'Total Bwd packets' : 'Tot Bwd Pkts',
    'Total Fwd Packet' : 'Tot Fwd Pkts',
    'Total Length of Bwd Packet' : 'TotLen Bwd Pkts',
    'Total Length of Fwd Packet' : 'TotLen Fwd Pkts',
    'URG Flag Count' : 'URG Flag Cnt',
    'Bwd Init Win Bytes': 'Init Bwd Win Byts',
    'FWD Init Win Bytes': 'Init Fwd Win Byts',
}
test_test = new.rename(columns=namere)

# %%
for col in test.columns:
    if col not in benign.columns:
        print(col)

# Dst IP
# Flow ID
# Src IP
# Src Port
# Out:
# Flow ID
# Src IP
# Src Port
# Dst IP

# %%
print(new.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 84 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ACK Flag Count              34 non-null     object
#  1   Active Max                  34 non-null     object
#  2   Active Mean                 34 non-null     object
#  3   Active Min                  34 non-null     object
#  4   Active Std                  34 non-null     object
#  5   Average Packet Size         34 non-null     object
#  6   Bwd Bulk Rate Avg           34 non-null     object
#  7   Bwd Bytes/Bulk Avg          34 non-null     object
#  8   Bwd Header Length           34 non-null     object
#  9   Bwd IAT Max                 34 non-null     object
#  10  Bwd IAT Mean                34 non-null     object
#  11  Bwd IAT Min                 34 non-null     object
#  12  Bwd IAT Std                 34 non-null     object
#  13  Bwd IAT Total               34 non-null     object
#  14  Bwd Init Win Bytes          34 non-null     object
#  15  Bwd PSH Flags               34 non-null     object
#  16  Bwd Packet Length Max       34 non-null     object
#  17  Bwd Packet Length Mean      34 non-null     object
#  18  Bwd Packet Length Min       34 non-null     object
#  19  Bwd Packet Length Std       34 non-null     object
#  20  Bwd Packet/Bulk Avg         34 non-null     object
#  21  Bwd Packets/s               34 non-null     object
#  22  Bwd Segment Size Avg        34 non-null     object
#  23  Bwd URG Flags               34 non-null     object
#  24  CWR Flag Count              34 non-null     object
#  25  Down/Up Ratio               34 non-null     object
#  26  Dst IP                      34 non-null     object
#  27  Dst Port                    34 non-null     object
#  28  ECE Flag Count              34 non-null     object
#  29  FIN Flag Count              34 non-null     object
#  30  FWD Init Win Bytes          34 non-null     object
#  31  Flow Bytes/s                34 non-null     object
#  32  Flow Duration               34 non-null     object
#  33  Flow IAT Max                34 non-null     object
#  34  Flow IAT Mean               34 non-null     object
#  35  Flow IAT Min                34 non-null     object
#  36  Flow IAT Std                34 non-null     object
#  37  Flow ID                     34 non-null     object
#  38  Flow Packets/s              34 non-null     object
#  39  Fwd Act Data Pkts           34 non-null     object
#  40  Fwd Bulk Rate Avg           34 non-null     object
#  41  Fwd Bytes/Bulk Avg          34 non-null     object
#  42  Fwd Header Length           34 non-null     object
#  43  Fwd IAT Max                 34 non-null     object
#  44  Fwd IAT Mean                34 non-null     object
#  45  Fwd IAT Min                 34 non-null     object
#  46  Fwd IAT Std                 34 non-null     object
#  47  Fwd IAT Total               34 non-null     object
#  48  Fwd PSH Flags               34 non-null     object
#  49  Fwd Packet Length Max       34 non-null     object
#  50  Fwd Packet Length Mean      34 non-null     object
#  51  Fwd Packet Length Min       34 non-null     object
#  52  Fwd Packet Length Std       34 non-null     object
#  53  Fwd Packet/Bulk Avg         34 non-null     object
#  54  Fwd Packets/s               34 non-null     object
#  55  Fwd Seg Size Min            34 non-null     object
#  56  Fwd Segment Size Avg        34 non-null     object
#  57  Fwd URG Flags               34 non-null     object
#  58  Idle Max                    34 non-null     object
#  59  Idle Mean                   34 non-null     object
#  60  Idle Min                    34 non-null     object
#  61  Idle Std                    34 non-null     object
#  62  Label                       34 non-null     object
#  63  PSH Flag Count              34 non-null     object
#  64  Packet Length Max           34 non-null     object
#  65  Packet Length Mean          34 non-null     object
#  66  Packet Length Min           34 non-null     object
#  67  Packet Length Std           34 non-null     object
#  68  Packet Length Variance      34 non-null     object
#  69  Protocol                    34 non-null     object
#  70  RST Flag Count              34 non-null     object
#  71  SYN Flag Count              34 non-null     object
#  72  Src IP                      34 non-null     object
#  73  Src Port                    34 non-null     object
#  74  Subflow Bwd Bytes           34 non-null     object
#  75  Subflow Bwd Packets         34 non-null     object
#  76  Subflow Fwd Bytes           34 non-null     object
#  77  Subflow Fwd Packets         34 non-null     object
#  78  Timestamp                   34 non-null     object
#  79  Total Bwd packets           34 non-null     object
#  80  Total Fwd Packet            34 non-null     object
#  81  Total Length of Bwd Packet  34 non-null     object
#  82  Total Length of Fwd Packet  34 non-null     object
#  83  URG Flag Count              34 non-null     object
# dtypes: object(84)
# memory usage: 22.4+ KB
# None
